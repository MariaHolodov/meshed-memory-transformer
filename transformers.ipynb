# %% [markdown]
# <a href="https://colab.research.google.com/github/MariaHolodov/meshed-memory-transformer/blob/master/transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# from google.colab import auth
# auth.authenticate_user()
# project_id = 'powerful-memory-317309'
# !gcloud config set project {project_id}
# !gsutil ls

# %%
#!gsutil -o GSUtil:parallel_composite_upload_threshold=150M cp -r /content/drive/My\ Drive/DeepLearningCourseHW/project/*.hdf5 gs://deep_learning_project_docodata/   

#!curl -L "https://drive.google.com/u/0/uc?id=1MV6dSnqViQfyvgyHrmAT_lLpFbkzp3mx&export=download" gs://deep_learning_project_docodata/   

#!gsutil -m cp -r /content/drive/My\ Drive/DeepLearningCourseHW/project/*.hdf5 gs://deep_learning_project_docodata/

# %% [markdown]
# Download Anaconda 3.6, and create env from yml file - run only ones, and save created env for feature use

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local/
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
#
# which conda # should return /usr/local/bin/conda
# conda --version # should return 4.5.4
# which python # still returns /usr/local/bin/python
#
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes
#
# conda --version # now returns 4.8.3
# python --version # now returns Python 3.6.10 :: Anaconda, Inc.
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
import sys
sys.path
# !ls /usr/local/lib/python3.6/dist-packages
_ = (sys.path
        .append("/usr/local/lib/python3.6/site-packages"))

#import os
#path = '/content/miniconda3/bin:' + os.environ['PATH']
#%env PATH=$path

import os
os.chdir("/content/drive/MyDrive/DeepLearningCourseHW/project/")
# !conda env create -f environment.yml
# Out:
# CondaValueError: prefix already exists: /usr/local/envs/m2release

# %% [markdown]
# Save created envierment to Drive

# %%
#!tar -zcf conda_colab.tar.gz /usr/local
#!cp conda_colab.tar.gz /content/drive/MyDrive/DeepLearningCourseHW/project

# %% [markdown]
# Load Enviermant

# %%
#!tar -xf /content/drive/MyDrive/DeepLearningCourseHW/project/conda_colab.tar.gz -C ../

#import os
#path = '/usr/local/bin:' + os.environ['PATH']
#%env PATH=$path
#%env PYTHONPATH=
#import sys
#sys.path
#!ls /usr/local/lib/python3.6/dist-packages
#_ = (sys.path
#        .append("/usr/local/lib/python3.6/site-packages"))

# %%
import os

os.chdir("/content/drive/MyDrive/DeepLearningCourseHW/project/")
# !ls
# Out:
#  annotations			      models
#  coco_detections.hdf5		      output_logs
#  conda_colab.tar.gz		      pkgs
#  conda-meta			      README.md
#  Copyofcoco_detections.hdf5	      requirment.txt
# 'Copy of transformers.ipynb'	      tensorboard_logs
#  data				      test2.py
#  environment.yml		      testH5.ipynb
#  evaluation			      test.py
#  images				      train.py
#  LICENSE			      transformers.ipynb
#  LICENSE.txt			      utils
#  meshed_memory_transformer.pth	      vocab_a.pkl
#  Miniconda3-4.5.4-Linux-x86_64.sh     vocab.pkl
#  Miniconda3-4.5.4-Linux-x86_64.sh.4

# %%
# !source activate m2release && python -m spacy download en
# Out:
# ...
#      |████████████████████████████████| 37.4MB 1.3MB/s
# ...
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.0.0-cp36-none-any.whl size=37405977 sha256=d872dc7db76c182fb1e8aa0211ad7a3501c10cb688f6fe51594b04de62510ee8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-50mn54o9/wheels/54/7c/d8/f86364af8fbba7258e14adae115f18dd2c91552406edc3fdaa
# Successfully built en-core-web-sm
#
#     Linking successful
#     /usr/local/envs/m2release/lib/python3.6/site-packages/en_core_web_sm -->
#     /usr/local/envs/m2release/lib/python3.6/site-packages/spacy/data/en
#
#     You can now load the model via spacy.load('en')

# %%
# !source activate m2release && python test.py --batch_size	 10 --annotation_folder	annotations --features_path Copyofcoco_detections.hdf5
# Out:
# Traceback (most recent call last):
#   File "test.py", line 2, in <module>
#     from data import ImageDetectionsField, TextField, RawField
#   File "/content/drive/MyDrive/DeepLearningCourseHW/project/data/__init__.py", line 1, in <module>
#     from .field import RawField, Merge, ImageDetectionsField, TextField
#   File "/content/drive/MyDrive/DeepLearningCourseHW/project/data/field.py", line 13, in <module>
#     from .dataset import Dataset
#   File "/content/drive/MyDrive/DeepLearningCourseHW/project/data/dataset.py", line 8, in <module>
#     from pycocotools.coco import COCO as pyCOCO
#   File "/usr/local/envs/m2release/lib/python3.6/site-packages/pycocotools/coco.py", line 49, in <module>
#     import matplotlib.pyplot as plt
#   File "/usr/local/envs/m2release/lib/python3.6/site-packages/matplotlib/pyplot.py", line 115, in <module>
#     _backend_mod, new_figure_manager, draw_if_interactive, _show = pylab_setup()
# ...

# %%
# !source activate m2release && python train.py --exp_name	'a'  --annotation_folder	annotations --features_path coco_detections.hdf5
# Out:
# 3.3.0
# Namespace(annotation_folder='annotations', batch_size=10, exp_name='a', features_path='coco_detections.hdf5', head=8, logs_folder='tensorboard_logs', m=40, resume_best=False, resume_last=False, warmup=10000, workers=0)
# Meshed-Memory Transformer Training
# Traceback (most recent call last):
#   File "train.py", line 190, in <module>
#   File "/content/drive/My Drive/DeepLearningCourseHW/project/evaluation/cider/cider.py", line 25, in __init__
#     tmp_cider = CiderScorer(gts, n=self._n, sigma=self._sigma)
#   File "/content/drive/My Drive/DeepLearningCourseHW/project/evaluation/cider/cider_scorer.py", line 68, in __init__
#     self.compute_doc_freq()
#   File "/content/drive/My Drive/DeepLearningCourseHW/project/evaluation/cider/cider_scorer.py", line 85, in compute_doc_freq
#     self.doc_frequency[ngram] += 1
# KeyboardInterrupt
# ^C

# %%
# !source activate m2release && pip install ipykernel
# Out:
# ...
#      |████████████████████████████████| 122kB 26.8MB/s
# ...
#      |████████████████████████████████| 81kB 11.2MB/s
# ...
#      |████████████████████████████████| 122kB 24.9MB/s
# ...
#      |████████████████████████████████| 788kB 37.2MB/s
# ...
#      |████████████████████████████████| 430kB 47.0MB/s
# ...
#      |████████████████████████████████| 92kB 12.4MB/s
# ...
#      |████████████████████████████████| 1.1MB 40.0MB/s
# ...
#      |████████████████████████████████| 61kB 9.4MB/s
# ...
#      |████████████████████████████████| 1.4MB 36.9MB/s
# ...
#      |████████████████████████████████| 368kB 48.7MB/s
# ...
#      |████████████████████████████████| 1.0MB 37.6MB/s
# ...
#      |████████████████████████████████| 102kB 13.6MB/s
# ...

# %%
# !source activate m2release && python test2.py
# Out:
# 5.5.5

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.2.2
